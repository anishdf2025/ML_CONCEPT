# %% [markdown]
# # Activation Function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\91955\anaconda3\envs\new_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Linear Activation Function
# -----------------------------
def linear(x):
    return x

# Generate values
x = np.linspace(-10, 10, 400)
y = linear(x)

# Plotting
plt.figure(figsize=(7,5))
plt.plot(x, y, label='f(x) = x', linewidth=1)

plt.title("Linear Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
def sigmoid(x):
    return 1/(1+np.exp(-x))
x=np.linspace(-10,10,500)
y=sigmoid(x)
plt.figure(figsize=(7,5))
plt.plot(x,y,label='(1/(1+np.exp(-x)))',linewidth=2)
plt.title("Sigmoid activation function")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
def Relu_activation(x):
    return np.maximum(0,x)
x=np.linspace(-10,10,500)
y=Relu_activation(x)
plt.figure(figsize=(7,5))
plt.plot(x,y,label='ReLU',linewidth=2)
plt.title("ReLU Activation function")
plt.xlabel("x-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
def Leaky_Relu_activation(x):
    return np.maximum(0.1*x,x)
x=np.linspace(-10,10,500)
y=Leaky_Relu_activation(x)
plt.figure(figsize=(7,5))
plt.title("LeakyReLU Activation function")
plt.plot(x,y,label='LeakyRelu',linewidth=2)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
import matplotlib.pyplot as plt
def tan(x):
    return np.tanh(x)
x=np.linspace(-10,10,500)
y=tan(x)
plt.figure(figsize=(7,5))
plt.plot(x,y,label='Tanh',linewidth=2)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
