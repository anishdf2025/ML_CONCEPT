# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ✅ When to use OpenAI API key
#
# # ✅ When to use your own custom model + GPU + vLLM/TRT-LLM

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <!-- ✅ When to use OpenAI API key
# ✅ When to use your own custom model + GPU + vLLM/TRT-LLM -->

# %% [markdown]
# <!-- ✅ When to use OpenAI API key
# ✅ When to use your own custom model + GPU + vLLM/TRT-LLM -->
